# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import arviz as az
from sklearn.linear_model import LogisticRegression
import pymc3 as pm

# %% [markdown]
# ## The Dataset
#
# You can download the dataset from here: https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database

# %%
## 1 point
diab_df=pd.read_csv('diabetes.csv')
diab_df.head()
## ToDo: read the csv file into a dataframe and show the first 5 rows
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
## 3 points
## Assign the Outcome variable to y and the rest to X.
## Use LogisticRegression to fit the data and print out the intercept and the coefficients
y=diab_df['Outcome']
X=diab_df.loc[:, diab_df.columns != 'Outcome']

clf = LogisticRegression(random_state=0).fit(X, y)
print(clf.intercept_)``
print(clf.coef_)
#clf.predict(X)
# Out:
# [-7.70292768]
# [[ 1.17252350e-01  3.36000076e-02 -1.40873332e-02 -1.27042278e-03
#   -1.24033067e-03  7.72021578e-02  1.41904228e+00  1.00352115e-02]]
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
## 2 points

## Explain what the code is doing:
## What are the prior probabilities of the intercept and coefficients?
# Which likelihood distribution has been used?
## What does pm.invlogit(linreg) mean?
## What is map_est?

with pm.Model() as logreg_model:
  
    w0 = pm.Normal('w0', mu=0, sd=100)
    w1 = pm.Normal('w1', mu=0, sd=100)
    w2 = pm.Normal('w2', mu=0, sd=100)
    w3 = pm.Normal('w3', mu=0, sd=100)
    w4 = pm.Normal('w4', mu=0, sd=100)
    w5 = pm.Normal('w5', mu=0, sd=100)
    w6 = pm.Normal('w6', mu=0, sd=100)
    w7 = pm.Normal('w7', mu=0, sd=100)
    w8 = pm.Normal('w8', mu=0, sd=100)
   
    
    linreg = w0 * np.ones(diab_df.shape[0]) + w1 * diab_df.Pregnancies.values + w2 * diab_df.Glucose.values \
    + w3 * diab_df.BloodPressure.values + w4 * diab_df.SkinThickness.values + w5 * diab_df.Insulin.values + \
    w6 * diab_df.BMI.values + w7 * diab_df.DiabetesPedigreeFunction.values + w8 * diab_df.Age.values
    p_outcome = pm.invlogit(linreg)

    likelihood = pm.Bernoulli('likelihood', p_outcome, observed=diab_df.Outcome.values)

    
    map_est= pm.find_MAP()
    print(map_est)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='135' class='' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [135/135 00:00<00:00 logp = -411.44, ||grad|| = 12.242]
#     </div>
# {'w0': array(-8.40381811), 'w1': array(0.12319259), 'w2': array(0.03516101), 'w3': array(-0.01329351), 'w4': array(0.00062072), 'w5': array(-0.00119151), 'w6': array(0.08968112), 'w7': array(0.94539065), 'w8': array(0.0148632)}

# %% [markdown]
# #Explain what the code is doing:
# This code basically did a linear regression. It started by creating nine stochastic random varaibles with normal prior distribution with mean of zero and standard deviation of 100. Then calculate the likelihood by using bernoulli likelihood distribution. Finally we get the posterior estimates for the varaibles in the model by using find_MAP also known as find maximum a posterior.
# #What are the prior probabilities of the intercept and coefficients?
# The prior probabilities of the intercept and coefficients are from the normal distribution with a mean of zero and a standard deviation of 100. w0 is for the intercept, and the rest are coefficients for each of the columns.
# #Which likelihood distribution has been used?
# The bernoulli distribution was used for the likelihood.
# #What does pm.invlogit(linreg) mean?
# pm.invlogit(linreg) is putting the expected value calculated using the linear equation through the sigmoid function. So, P_outcome stores values calculated using the sigmoid function.
# #What is map_est?
# find_MAP calculates the posterior or the predicted coffecient for each variables w0 to w8. This is also known as the mode of the posterior. With that, map_est stores the modes of the posterior for each of the variables w0 to w8.

# %%
## 2 points

with logreg_model:
  ## ToDo: draw 400 samples using pm.Metropolis() and assign to the variable trace
  step = pm.Metropolis()
  trace = pm.sample(400,step,random_seed=123, progressbar=True)
  ## Explain the output of the plot 
  az.plot_posterior(trace)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#
# Only 400 samples in chain.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [w8]
# >Metropolis: [w7]
# >Metropolis: [w6]
# >Metropolis: [w5]
# >Metropolis: [w4]
# >Metropolis: [w3]
# >Metropolis: [w2]
# >Metropolis: [w1]
# >Metropolis: [w0]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
# ...

# %% [markdown]
# The output of the plots allows us to analyze the posterior. So as described in the notes, the sample did not converge. The r_hat values as shown in summary I printed above were far too great for most of the variables. That is also visible in the graph with none of the graph looking like a normal curve as their prior suggests. If the samples converged then the values of the mean would match up with the posterior calculated above and their graph would look more like a normal graph. In order to make the sample converge, we need to take more samples. Overall, the graphs show that only taking 400 samples is not enough.
#
# Link to the github:https://github.com/TaihangLi/Data606_hw6
